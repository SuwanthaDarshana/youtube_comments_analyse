# %%
pip install youtube-comment-downloader
# Out:
# Requirement already satisfied: youtube-comment-downloader in d:\campus\semester8\research model creation\youtube_comments_analyse\env\lib\site-packages (0.1.76)
# Requirement already satisfied: dateparser in d:\campus\semester8\research model creation\youtube_comments_analyse\env\lib\site-packages (from youtube-comment-downloader) (1.2.2)
# Requirement already satisfied: requests in d:\campus\semester8\research model creation\youtube_comments_analyse\env\lib\site-packages (from youtube-comment-downloader) (2.32.4)
# Requirement already satisfied: python-dateutil>=2.7.0 in d:\campus\semester8\research model creation\youtube_comments_analyse\env\lib\site-packages (from dateparser->youtube-comment-downloader) (2.9.0.post0)
# Requirement already satisfied: pytz>=2024.2 in d:\campus\semester8\research model creation\youtube_comments_analyse\env\lib\site-packages (from dateparser->youtube-comment-downloader) (2025.2)
# Requirement already satisfied: regex>=2024.9.11 in d:\campus\semester8\research model creation\youtube_comments_analyse\env\lib\site-packages (from dateparser->youtube-comment-downloader) (2024.11.6)
# Requirement already satisfied: tzlocal>=0.2 in d:\campus\semester8\research model creation\youtube_comments_analyse\env\lib\site-packages (from dateparser->youtube-comment-downloader) (5.3.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\campus\semester8\research model creation\youtube_comments_analyse\env\lib\site-packages (from requests->youtube-comment-downloader) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\campus\semester8\research model creation\youtube_comments_analyse\env\lib\site-packages (from requests->youtube-comment-downloader) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\campus\semester8\research model creation\youtube_comments_analyse\env\lib\site-packages (from requests->youtube-comment-downloader) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\campus\semester8\research model creation\youtube_comments_analyse\env\lib\site-packages (from requests->youtube-comment-downloader) (2025.7.14)
# Requirement already satisfied: six>=1.5 in d:\campus\semester8\research model creation\youtube_comments_analyse\env\lib\site-packages (from python-dateutil>=2.7.0->dateparser->youtube-comment-downloader) (1.17.0)
# Requirement already satisfied: tzdata in d:\campus\semester8\research model creation\youtube_comments_analyse\env\lib\site-packages (from tzlocal>=0.2->dateparser->youtube-comment-downloader) (2025.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install googletrans==4.0.0-rc1
# Out:
# Requirement already satisfied: googletrans==4.0.0-rc1 in d:\campus\semester8\research model creation\youtube_comments_analyse\env\lib\site-packages (4.0.0rc1)
# Requirement already satisfied: httpx==0.13.3 in d:\campus\semester8\research model creation\youtube_comments_analyse\env\lib\site-packages (from googletrans==4.0.0-rc1) (0.13.3)
# Requirement already satisfied: certifi in d:\campus\semester8\research model creation\youtube_comments_analyse\env\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2025.7.14)
# Requirement already satisfied: hstspreload in d:\campus\semester8\research model creation\youtube_comments_analyse\env\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2025.1.1)
# Requirement already satisfied: sniffio in d:\campus\semester8\research model creation\youtube_comments_analyse\env\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.3.1)
# Requirement already satisfied: chardet==3.* in d:\campus\semester8\research model creation\youtube_comments_analyse\env\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (3.0.4)
# Requirement already satisfied: idna==2.* in d:\campus\semester8\research model creation\youtube_comments_analyse\env\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2.10)
# Requirement already satisfied: rfc3986<2,>=1.3 in d:\campus\semester8\research model creation\youtube_comments_analyse\env\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.5.0)
# Requirement already satisfied: httpcore==0.9.* in d:\campus\semester8\research model creation\youtube_comments_analyse\env\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (0.9.1)
# Requirement already satisfied: h11<0.10,>=0.8 in d:\campus\semester8\research model creation\youtube_comments_analyse\env\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (0.9.0)
# Requirement already satisfied: h2==3.* in d:\campus\semester8\research model creation\youtube_comments_analyse\env\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (3.2.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in d:\campus\semester8\research model creation\youtube_comments_analyse\env\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in d:\campus\semester8\research model creation\youtube_comments_analyse\env\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (3.0.0)
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import re
import string
import torch
import joblib
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from youtube_comment_downloader import YoutubeCommentDownloader
from googletrans import Translator

# ---- Extract YouTube Video ID ----
def extract_video_id(url):
    match = re.search(r"(?:v=|\/)([0-9A-Za-z_-]{11}).*", url)
    return match.group(1) if match else None

# ---- Comment Extraction ----
def get_youtube_comments(video_url, max_comments=100):
    try:
        video_id = extract_video_id(video_url)
        if not video_id:
            raise ValueError("Invalid YouTube URL")
        downloader = YoutubeCommentDownloader()
        comments = []
        for comment in downloader.get_comments_from_url(f"https://www.youtube.com/watch?v={video_id}"):
            comments.append(comment['text'])
            if len(comments) >= max_comments:
                break
        return comments
    except Exception as e:
        print("Error while fetching comments:", e)
        return []

# ---- Translation ----
translator = Translator()
def is_sinhala(text):
    return bool(re.search(r'[\u0D80-\u0DFF]', text))

def translate_to_sinhala_if_needed(comments):
    translated_comments = []
    for comment in comments:
        comment = comment.strip()
        if not comment:
            continue  # skip empty strings
        if is_sinhala(comment):
            translated_comments.append(comment)
        else:
            try:
                translation = translator.translate(comment, src='auto', dest='si')
                translated_comments.append(translation.text.strip())
            except Exception as e:
                print(f"Translation failed: {e}")
                translated_comments.append(comment)  # fallback
    return translated_comments

# ---- Preprocessing ----
sinhala_stopwords = set("""සහ සමග සමඟ අහා ආහ් ආ ඕහෝ අනේ අඳෝ අපොයි අපෝ අයියෝ ආයි ඌයි චී චිහ් චික් හෝ‍ දෝ දෝහෝ මෙන්
සේ වැනි බඳු වන් අයුරු අයුරින් ලෙස වැඩි ශ්‍රී හා ය නිසා නිසාවෙන් බවට බව බවෙන් නම් වැඩි සිටදී මහා මහ
පමණ පමණින් පමන වන විට විටින් මේ මෙලෙස මෙයින් ඇති ලෙස සිදු වශයෙන් යන සඳහා මගින් හෝ‍ ඉතා ඒ එම ද
අතර විසින් සමග පිළිබඳව පිළිබඳ තුළ බව වැනි මහ මෙම මෙහි මේ වෙත වෙතින් වෙතට වෙනුවෙන් වෙනුවට
වෙන ගැන නෑ අනුව නව පිළිබඳ විශේෂ දැනට එහෙන් මෙහෙන් එහේ මෙහේ ම තවත් තව දක්වා ට ගේ එ ක ක්
බවත් බවද මත ඇතුලු ඇතුළු මෙසේ වැඩි වඩා වඩාත්ම නිති නිතිත් නිතොර නිතර ඉක්බිති දැන් යලි පුන ඉතින් සිට
සිටන් පටන් තෙක් දක්වා සා තාක් තුවක් පවා ද හෝ‍ වත් විනා හැර මිස මුත් කිම කිම් ඇයි මන්ද හෙවත් නොහොත්
පතා පාසා ගානෙ තව ඉතා බොහෝ වහා සෙද සැනින් හනික එම්බා එම්බල බොල නම් වනාහි කලී ඉඳුරා අන්න ඔන්න
මෙන්න උදෙසා පිණිස සඳහා අරබයා නිසා එනිසා එබැවින් බැවින් හෙයින් සේක් සේක ගැන අනුව පරිදි විට තෙක්
මෙතෙක් මේතාක් තුරු තුරා තුරාවට තුලින් නමුත් එනමුත් වස් මෙන් ලෙස පරිදි එහෙත්""".split())  # stop wrds

def remove_links(text): return re.sub(r'https?://\S+|www\.\S+', '', text)
def remove_english(text): return re.sub(r'[a-zA-Z]', '', text)
def remove_punctuations(text): return text.translate(str.maketrans('', '', string.punctuation))
def remove_numbers(text): return re.sub(r'\d+', '', text)
def remove_non_sinhala(text): return re.sub(r'[^\u0D80-\u0DFF\s]', '', str(text))
def remove_emojis(text):
    emoji_pattern = re.compile(
        "["  # opening square bracket for character class
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags
        u"\U00002700-\U000027BF"
        u"\U000024C2-\U0001F251"
        "]",  # closing square bracket for character class
        flags=re.UNICODE
    )
    return emoji_pattern.sub(r'', text)

def remove_sinhala_stopwords(text):
    return " ".join([word for word in text.split() if word not in sinhala_stopwords])

def full_clean(text):
    text = text.strip()
    text = remove_links(text)
    text = remove_emojis(text)
    text = remove_english(text)
    text = remove_punctuations(text)
    text = remove_numbers(text)
    text = remove_non_sinhala(text)
    text = remove_sinhala_stopwords(text)
    return text.strip()

def preprocess_comments(comments):
    return [full_clean(c) for c in comments if c.strip()]

# ---- Tokenizer ----
tokenizer = AutoTokenizer.from_pretrained("saved_model")
def tokenize_combined_text(text):
    return tokenizer(text, padding=True, truncation=True, max_length=128, return_tensors="pt")         # all comments combined

# ---- Load Model and LabelEncoder ----
model = AutoModelForSequenceClassification.from_pretrained("saved_model")
label_encoder = joblib.load("saved_model/label_encoder.joblib")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
model.eval()

# ---- Main Function ----
def predict_youtube_category(video_url):
    print("🔍 Fetching comments...")
    comments = get_youtube_comments(video_url)
    if not comments:
        print("❌ No comments fetched.")
        return None

    print(f"🗣 Translating and cleaning {len(comments)} comments...")
    comments = translate_to_sinhala_if_needed(comments)
    cleaned_comments = preprocess_comments(comments)

    print("\n🧹 Preprocessed Comments Sample:")
    for i, comment in enumerate(cleaned_comments[:100], start=1):
        print(f"{i}. {comment}")


    if not cleaned_comments:
        print("❌ All comments were empty after cleaning.")
        return None

    combined_text = " ".join(cleaned_comments)
    inputs = tokenize_combined_text(combined_text)
    inputs = {k: v.to(device) for k, v in inputs.items()}

    print("🤖 Predicting category...")
    with torch.no_grad():
        outputs = model(**inputs)
        logits = outputs.logits
        predicted_class_id = torch.argmax(logits, dim=1).item()   #Selects the class with the highest probability
        predicted_label = label_encoder.inverse_transform([predicted_class_id])[0] #converrt predicted category into label

    print(f"✅ Predicted Category: **{predicted_label}**")
    return predicted_label

# %%
predict_youtube_category("https://www.youtube.com/watch?v=SJAcSo84hIA")
# Out:
# 🔍 Fetching comments...
# 🗣 Translating and cleaning 100 comments...
#
# 🧹 Preprocessed Comments Sample:
# 1. ඌ තාප්පෙට ඇල්ලුවනම් ඔක පෙරලීලා ඔයිට හානියක් වෙන්න තිබුනා බරවාහන රාත්රී උදේ පමනක් දාවනය කල යුතූ කලානම් හරී
# 2. අනතුර වලක්වා ගත්තෙ නැහැ කියලා යට උන් මිනිස්සුන්ට නඩු දාන රටක් යකො මේක
# 3. ඔය බයිසිකල් උඩින් ගියා කියාපු කෙනා ගුටි කැවා උඩින් යන්න
# 4. මෝඩ පොලිසිය ඔබ වතාවේ කාලයාගේ ඇවෑමෙන්
# 5. පුලුගුලියානු හි සහිත උච්චාරා දයාරා තණකොළ
# 6.
# 7. වැගන් අර් එක අපරාදේ හරි පාරේ ගිහින් ටැරැක් එක මාරු කරන්න ගිහින් වදින්නෙ
# 8. නොදකින් අනුරලා ඇවිල්ල මෙිවාගේ පාදඩයන්ට නිසි දඩුවමි නිතියේ ආධිපත්යය කොරයිකියලා හිතා හිටියා උන්ට කොරන්න බැහැ රටෙි අහිංසක මිනිස්සු මැරෙන්නේ මෙි වගේ පාඩද රියදුරන් ඔිකව ගහල මරන්න ඔිනැ එවෙලෙම කෝ රටෙි නිතිය
# 9. හාරාමා මකාවි තුන්වැල්ල බලා නොසිටින්න
# 10. අපේ රටේ නීතිය කරන්නඑතකොට අඩු වෙවි
# 11. එමවාචික නොවන මිනි වාහනය
# 12. ජනතා විමුක්ති පෙරමුනට සම්බන්ධ නිධානයක් ගොඩගැනිමට හදිසේයේ ශානිලාගේ මැදිහත්වීමේන් වෙගයෙන් ගෙන්වා ගැනීම නීසා පාලනය කරගැනිමට හැකිව යටවි ඇත
# 13. බස් ත් ඔහොම තමයි යන්නෙ ලගදී මම බේරුනේ දශමෙන්
# 14. තනිකරම වගකීඑම් විරහිතවභාවය් රෑ හොදට බීලා නිට්දිමතේ එන්න ඇත්තේ බ්රේක් නැති කතා බොරු
# 15. පුදුමයි එතන වාහන අඩු එක
# 16. මටනම් පේන්නේ වාහනේ බ්රේක් අල්ලන් නැති කේස් එකක් තියෙන්නේ
# 17. කාලකන්නි එල්ලා මරන්න ඕ නි අරාබි නීති තමයි හරි
# 18. මේ පකයන්ව මරන්න ඕන ලයිසන් කැන්සල් කරලා වැඩක් නෑමාලිමා රජයක් අපි ගෙනාවේ කලින් තිබුන විදියටම රට කරගෙන යන්න නෙවෙයි මිනීමරැවන්ට මරන දඩුවම දීලා මේවා නතර කරන්න තොපිටත් කොන්ද පන නැත්තන් අායේ චන්ද නෑමැරැන අයගේ ලමයිබිරිද බලාගෙන ඉන්න අැති තාත්තා ගෙදර එනකම්
